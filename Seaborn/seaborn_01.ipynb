# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # we are now discussing about the distribution plot's like displots/histplot, jointplot, pairplot, rugplot, etc

# %%
df = sns.load_dataset('tips')
df['size'].unique()
print(df)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.subplot(1,2,1)
sns.histplot(df['total_bill'], kde=True , color='gold')

plt.subplot(1,2,2)
sns.histplot(df['tip'], kde=True, color='green')

sns.jointplot(x='total_bill', y='tip', data=df, kind='hist', color='red')

# %%
sns.pairplot(df, hue='smoker')

# %% [markdown]
# ## categorical plot's

# %%
df  = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x= df['sex'], hue= df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.barplot(x= df['sex'], y= df['total_bill'], )
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x= df['sex'], y= df['tip'], estimator=np.sum)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="dark")
fmri = sns.load_dataset("fmri")

# Plot the responses for different\
# events and regions
sns.lineplot(x="timepoint",
             y="signal",
             hue="region",
             style="event",
             data=fmri)
plt.show()

# %%
sns.boxenplot(x= 'total_bill', y = 'sex', data = df, palette='rainbow')
# Out:
# C:\Users\happy\AppData\Local\Temp\ipykernel_18840\101197589.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x= 'total_bill', y = 'sex', data = df, palette='rainbow')
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
sns.violinplot(x='day', y = 'total_bill', data = df , palette='rainbow')
# Out:
# C:\Users\happy\AppData\Local\Temp\ipykernel_18840\366947754.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='day', y = 'total_bill', data = df , palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x= 'day', y='total_bill' , data=df , palette='rainbow')
# Out:
# C:\Users\happy\AppData\Local\Temp\ipykernel_18840\3810717980.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x= 'day', y='total_bill' , data=df , palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x = 'day', y = 'total_bill' , data = df , palette='rainbow')
# Out:
# C:\Users\happy\AppData\Local\Temp\ipykernel_18840\1130854728.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x = 'day', y = 'total_bill' , data = df , palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>
